#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23                15                 0
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0
# 36                 0                 0

# %% [markdown]
# Data Understanding

# %%
df.shape
# Out:
# (37, 14)

# %%
df.isnull().sum()
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# actualdeath24hrs    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
#  13  actualdeath24hrs  37 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 4.2+ KB

# %%
df.describe()
# Out:
#              sno       active      positive         cured         death  \
# count  37.000000    37.000000  3.700000e+01  3.700000e+01      37.00000
# mean   19.000000    79.297297  2.432265e+06  2.403365e+06   28752.27027
# std    10.824355   288.505138  7.418699e+06  7.329620e+06   89151.92635
# min     1.000000     0.000000  1.076600e+04  1.063700e+04       4.00000
# 25%    10.000000     0.000000  1.084200e+05  1.074540e+05    1185.00000
# 50%    19.000000     2.000000  7.461500e+05  7.381150e+05    7768.00000
# 75%    28.000000     9.000000  1.348362e+06  1.339084e+06   14733.00000
# max    37.000000  1467.000000  4.499691e+07  4.446224e+07  531917.00000
#
#         new_active  new_positive     new_cured     new_death  state_code  \
# count    37.000000  3.700000e+01  3.700000e+01      37.00000   37.000000
# mean     79.675676  2.432267e+06  2.403366e+06   28752.27027   18.324324
# std     289.446987  7.418704e+06  7.329624e+06   89151.92635   11.212726
# min       0.000000  1.076600e+04  1.063700e+04       4.00000    0.000000
# 25%       0.000000  1.084280e+05  1.074600e+05    1185.00000    9.000000
# 50%       2.000000  7.461500e+05  7.381150e+05    7768.00000   18.000000
# 75%       8.000000  1.348367e+06  1.339088e+06   14733.00000   28.000000
# max    1474.000000  4.499695e+07  4.446227e+07  531917.00000   37.000000
#
#        actualdeath24hrs
# count              37.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0

# %%
df.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.nunique()
# Out:
# sno                 37
# state_name          37
# active              18
# positive            37
# cured               37
# death               37
# new_active          16
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     1
# total                1
# state_code          37
# actualdeath24hrs     1
# dtype: int64

# %%
df.tail()
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura      25    108420    107454     941          27
# 33   34    Uttarakhand       1    452560    444791    7768           0
# 34   35  Uttar Pradesh      64   2145413   2121642   23707          65
# 35   36    West Bengal     190   2125750   2104008   21552         196
# 36   37                   1467  44996910  44462245  531917        1474
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 32        108428     107460        941                                 16
# 33        452560     444792       7768                                  5
# 34       2145414    2121642      23707                                  9
# 35       2125756    2104008      21552                                 19
# 36      44996946   44462274     531917                                  0
#
#     actualdeath24hrs
# 32                 0
# 33                 0
# 34                 0
# 35                 0
# 36                 0

# %%
df=df.iloc[:36]
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands       0     10766    10637
# 1     2                            Andhra Pradesh       1   2340674  2325940
# 2     3                         Arunachal Pradesh       0     67049    66753
# 3     4                                     Assam       0    746150   738115
# 4     5                                     Bihar       1    855260   842945
# 5     6                                Chandigarh       2    100693    99506
# 6     7                              Chhattisgarh       1   1187691  1173500
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11592    11588
# 8     9                                     Delhi       5   2040817  2014147
# 9    10                                      Goa*       6    263331   259311
# 10   11                                   Gujarat       9   1291364  1280276
# 11   12                                   Haryana      24   1078885  1068106
# 12   13                          Himachal Pradesh       9    322866   318616
# 13   14                         Jammu and Kashmir       1    482021   477228
# 14   15                                 Jharkhand       0    443825   438491
# 15   16                                 Karnataka       8   4088692  4048327
# 16   17                                 Kerala***    1015   6907109  6834148
# 17   18                                    Ladakh       0     29587    29356
# 18   19                               Lakshadweep       0     11415    11363
# 19   20                            Madhya Pradesh       0   1056351  1045565
# 20   21                               Maharashtra      70   8170147  8021521
# 21   22                                   Manipur       3    140031   137879
# 22   23                                 Meghalaya       2     96965    95335
# 23   24                                   Mizoram       0    239555   238821
# 24   25                                  Nagaland       1     36032    35249
# 25   26                                    Odisha      10   1348362  1339084
# 26   27                                Puducherry       0    177545   175564
# 27   28                                  Punjab**       2    793636   773068
# 28   29                                 Rajasthan       0   1326461  1316725
# 29   30                                    Sikkim       4     44879    44375
# 30   31                                Tamil Nadu       7   3610628  3572540
# 31   32                                 Telangana       6    844388   840271
# 32   33                                   Tripura      25    108420   107454
# 33   34                               Uttarakhand       1    452560   444791
# 34   35                             Uttar Pradesh      64   2145413  2121642
# 35   36                               West Bengal     190   2125750  2104008
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           0         10766      10637        129
# 1    14733           1       2340674    2325940      14733
# 2      296           0         67049      66753        296
# 3     8035           0        746150     738115       8035
# 4    12314           1        855260     842945      12314
# 5     1185           2        100693      99506       1185
# 6    14190           1       1187691    1173500      14190
# 7        4           0         11592      11588          4
# 8    26665           4       2040817    2014148      26665
# 9     4014           3        263331     259314       4014
# 10   11079           4       1291364    1280281      11079
# 11   10755          24       1078885    1068106      10755
# 12    4241           8        322866     318617       4241
# 13    4792           0        482021     477229       4792
# 14    5334           0        443825     438491       5334
# 15   40357          11       4088697    4048329      40357
# 16   71946        1014       6907109    6834149      71946
# 17     231           0         29587      29356        231
# 18      52           0         11415      11363         52
# 19   10786           0       1056351    1045565      10786
# 20  148556          75       8170155    8021524     148556
# 21    2149           2        140031     137880       2149
# 22    1628           2         96965      95335       1628
# 23     734           0        239555     238821        734
# 24     782           1         36032      35249        782
# 25    9215          11       1348367    1339088       9215
# 26    1981           0        177545     175564       1981
# 27   19338           2        793636     773068      19338
# 28    9736           0       1326461    1316725       9736
# 29     500           5         44880      44375        500
# 30   38081           7       3610628    3572540      38081
# 31    4111           8        844390     840271       4111
# 32     941          27        108428     107460        941
# 33    7768           0        452560     444792       7768
# 34   23707          65       2145414    2121642      23707
# 35   21552         196       2125756    2104008      21552
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23                15                 0
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0

# %% [markdown]
# Data Visualization

# %%
sns.pairplot(data=df)

# %%
cases_df=df.sum()
cases_df
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                           1467
# positive                                                     44996910
# cured                                                        44462245
# death                                                          531917
# new_active                                                       1474
# new_positive                                                 44996946
# new_cured                                                    44462274
# new_death                                                      531917
# death_reconsille
# total
# state_code                                                        678
# actualdeath24hrs                                                    0
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)

# %%
cases_df
# Out:
# active                  1467
# positive            44996910
# cured               44462245
# death                 531917
# new_active              1474
# new_positive        44996946
# new_cured           44462274
# new_death             531917
# death_reconsille
# total
# actualdeath24hrs           0
# dtype: object

# %%
my_data=['1420','44995900','44461286','531913']
my_label=['active','positive','cured','death']
my_explode=(0,0,0,1.5)
my_colour=['lightblue','lightsteelblue','lightpink','black']
fig1,ax1=plt.subplots(figsize=(13,8))
plt.pie(my_data,labels=my_label,autopct="%1.1f%%", startangle=15,shadow=True,colors=my_colour,explode=my_explode)
plt.axis('equal')
plt.show()

# %%
my_data=['1420','44995900','44461286','531913','1413','44995946','44461339','531913']
my_label=['active','positive','cured','death','new_active','new_positive','new_cured','new_death']
my_explode=(0,0,0,0,0,0,0,1.5)
my_colour=['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1,ax1=plt.subplots(figsize=(13,8))
plt.pie(my_data,labels=my_label,autopct="%1.1f%%", startangle=15,shadow=True,colors=my_colour,explode=my_explode)
plt.axis('equal')
plt.show()

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# <ipython-input-32-4b77f564f2d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['sno','state_code'],axis=1,inplace=True)

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       0     10766    10637    129           0
# 1               Andhra Pradesh       1   2340674  2325940  14733           1
# 2            Arunachal Pradesh       0     67049    66753    296           0
# 3                        Assam       0    746150   738115   8035           0
# 4                        Bihar       1    855260   842945  12314           1
#
#    new_positive  new_cured  new_death death_reconsille total  actualdeath24hrs
# 0         10766      10637        129                                        0
# 1       2340674    2325940      14733                                        0
# 2         67049      66753        296                                        0
# 3        746150     738115       8035                                        0
# 4        855260     842945      12314                                        0

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       0     10766    10637    129           0
# Andhra Pradesh                    1   2340674  2325940  14733           1
# Arunachal Pradesh                 0     67049    66753    296           0
# Assam                             0    746150   738115   8035           0
# Bihar                             1    855260   842945  12314           1
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10766      10637        129
# Andhra Pradesh                    2340674    2325940      14733
# Arunachal Pradesh                   67049      66753        296
# Assam                              746150     738115       8035
# Bihar                              855260     842945      12314
#
#                             death_reconsille total  actualdeath24hrs
# state_name
# Andaman and Nicobar Islands                                        0
# Andhra Pradesh                                                     0
# Arunachal Pradesh                                                  0
# Assam                                                              0
# Bihar                                                              0

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <Axes: ylabel='state_name'>

# %%
df1=df[['cured', 'death']]
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <Axes: ylabel='state_name'>

# %%
df2=df[['positive', 'death']]
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <Axes: ylabel='state_name'>

# %%
df3=df[['death', 'cured']]
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <Axes: ylabel='state_name'>

# %%
df4=df[['active', 'death']]
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <Axes: ylabel='state_name'>
